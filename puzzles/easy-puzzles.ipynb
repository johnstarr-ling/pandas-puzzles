# %% [markdown]
# # **Easy Puzzles**
# #### by John R. Starr
#
# Let's kickstart your `pandas` mastery. If you have any experience with the package, it is likely that most of this notebook will be review.
#
# To facilitate your use of documentation, all of the problems in this notebook can be solved with the following `pandas` functions and methods, presented in semi-random order (aka not the order that you'll use them in, but similar functions are often close to each other in the list):

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import random

# %% [markdown]
# `pandas` operates on DataFrames (shortened to DFs). DataFrames are visually similar to spreadsheets, but under the hood they are just grouped `numpy` arrays. DataFrames are easy to make:

# %%
sample_df = pd.DataFrame()

# Nothing's in here!
sample_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# You can make columns out of lists:
sample_df['students'] = ['Ashlyn', 'Srujan', 'Moon', 'Omer']

# ... and also out of numpy arrays:
sample_df['grades'] = np.random.randint(low=30, high=100, size=4)

sample_df
# Out:
#   students  grades
# 0   Ashlyn      52
# 1   Srujan      56
# 2     Moon      89
# 3     Omer      73

# %% [markdown]
# Printing DFs is not as pretty as returning them:

# %%
print(sample_df)
# Out:
#   students  grades
# 0   Ashlyn      52
# 1   Srujan      56
# 2     Moon      89
# 3     Omer      73

# %% [markdown]
# ... and the following code block let's us see every output in each cell without having to print anyway. So, don't no need to use `print`!

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# We'll be looking at one of the standard `seaborn` datasets called `titanic`. As you might've guessed from the title, the `titanic` dataset contains information about all of the passengers on the Titanic. Let's get started!

# %%
# Loading in the relevant dataset
titanic = sns.load_dataset('titanic')

# %% [markdown]
# ## Seeing Your Data

# %% [markdown]
# #### E1: Return the first seven lines of the `titanic` dataset.

# %%
# SOLUTION
titanic.head(7)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True

# %%
### YOUR CODE HERE

# %% [markdown]
# #### E2: Return nine random rows from the `titanic` dataset.
# Note: your output will almost certainly look different than mine, due to the random rows.

# %%
# SOLUTION
titanic.sample(9)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 503         0       3  female  37.0      0      0   9.5875        S   Third
# 310         1       1  female  24.0      0      0  83.1583        C   First
# 241         1       3  female   NaN      1      0  15.5000        Q   Third
# 314         0       2    male  43.0      1      1  26.2500        S  Second
# 62          0       1    male  45.0      1      0  83.4750        S   First
# 722         0       2    male  34.0      0      0  13.0000        S  Second
# 375         1       1  female   NaN      1      0  82.1708        C   First
# 290         1       1  female  26.0      0      0  78.8500        S   First
# 456         0       1    male  65.0      0      0  26.5500        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 503  woman       False  NaN  Southampton    no   True
# 310  woman       False    C    Cherbourg   yes   True
# 241  woman       False  NaN   Queenstown   yes  False
# 314    man        True  NaN  Southampton    no  False
# 62     man        True    C  Southampton    no  False
# 722    man        True  NaN  Southampton    no   True
# 375  woman       False  NaN    Cherbourg   yes  False
# 290  woman       False  NaN  Southampton   yes   True
# 456    man        True    E  Southampton    no   True

# %%
### YOUR CODE HERE

# %% [markdown]
# #### E3: Return the row with index 36 in the `titanic` dataset.

# %%
# Index by row index
titanic.loc[36]
# Out:
# survived               1
# pclass                 3
# sex                 male
# age                  NaN
# sibsp                  0
# parch                  0
# fare              7.2292
# embarked               C
# class              Third
# who                  man
# adult_male          True
# deck                 NaN
# embark_town    Cherbourg
# alive                yes
# alone               True
# Name: 36, dtype: object

# %%
### YOUR CODE HERE

# %% [markdown]
# #### E4: Return the number of people who lived and died in the `titanic` wreck.

# %%
# SOLUTION
titanic['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
### YOUR CODE HERE

# %% [markdown]
# ## Modifying your DFs

# %% [markdown]
# #### E5: Permanently rename the `embark_town` and `sibsp` to `left_from` and `num_dependents`, respectively.

# %%
# SOLUTION
titanic.rename(columns={'embark_town':"left_from", 'sibsp':'num_dependents'}, inplace=True)

# %%
### YOUR CODE HERE

# %% [markdown]
# #### E6: Convert all column labels to uppercase.

# %%
# SOLUTION
titanic.columns = [x.upper() for x in titanic.columns]

# %%
### YOUR CODE HERE

# %% [markdown]
# #### E7: Permanently delete the `WHO` column.

# %%
# SOLUTION
titanic.drop(columns=['WHO'], inplace=True)

# del titanic['WHO']

# %%
### YOUR CODE HERE

# %% [markdown]
# #### E8: Return a version of `titanic` that is sorted by passenger class, where first class is at bottom.

# %%
# SOLUTION
titanic.sort_values(by=['CLASS'], ascending=False)
# Out:
#      SURVIVED  PCLASS     SEX   AGE  NUM_DEPENDENTS  PARCH     FARE EMBARKED  \
# 0           0       3    male  22.0               1      0   7.2500        S
# 511         0       3    male   NaN               0      0   8.0500        S
# 500         0       3    male  17.0               0      0   8.6625        S
# 501         0       3  female  21.0               0      0   7.7500        Q
# 502         0       3  female   NaN               0      0   7.6292        Q
# ..        ...     ...     ...   ...             ...    ...      ...      ...
# 102         0       1    male  21.0               0      1  77.2875        S
# 710         1       1  female  24.0               0      0  49.5042        C
# 711         0       1    male   NaN               0      0  26.5500        S
# 712         1       1    male  48.0               1      0  52.0000        S
# 445         1       1    male   4.0               0      2  81.8583        S
#
#      CLASS  ADULT_MALE DECK    LEFT_FROM ALIVE  ALONE
# 0    Third        True  NaN  Southampton    no  False
# 511  Third        True  NaN  Southampton    no   True
# 500  Third        True  NaN  Southampton    no   True
# 501  Third       False  NaN   Queenstown    no   True
# 502  Third       False  NaN   Queenstown    no   True
# ..     ...         ...  ...          ...   ...    ...
# 102  First        True    D  Southampton    no  False
# 710  First       False    C    Cherbourg   yes   True
# 711  First        True    C  Southampton    no   True
# 712  First        True    C  Southampton   yes  False
# 445  First       False    A  Southampton   yes  False
#
# [891 rows x 14 columns]

# %%
# YOUR CODE HERE:

# %% [markdown]
# #### E9: Return the dataframe that consists of the first four lines and the last six lines of the `titanic` dataset.

# %%
# SOLUTION
pd.concat([titanic.head(4), titanic.tail(6)])
# Out:
#      SURVIVED  PCLASS     SEX   AGE  NUM_DEPENDENTS  PARCH     FARE EMBARKED  \
# 0           0       3    male  22.0               1      0   7.2500        S
# 1           1       1  female  38.0               1      0  71.2833        C
# 2           1       3  female  26.0               0      0   7.9250        S
# 3           1       1  female  35.0               1      0  53.1000        S
# 885         0       3  female  39.0               0      5  29.1250        Q
# 886         0       2    male  27.0               0      0  13.0000        S
# 887         1       1  female  19.0               0      0  30.0000        S
# 888         0       3  female   NaN               1      2  23.4500        S
# 889         1       1    male  26.0               0      0  30.0000        C
# 890         0       3    male  32.0               0      0   7.7500        Q
#
#       CLASS  ADULT_MALE DECK    LEFT_FROM ALIVE  ALONE
# 0     Third        True  NaN  Southampton    no  False
# 1     First       False    C    Cherbourg   yes  False
# 2     Third       False  NaN  Southampton   yes   True
# 3     First       False    C  Southampton   yes  False
# 885   Third       False  NaN   Queenstown    no  False
# 886  Second        True  NaN  Southampton    no   True
# 887   First       False    B  Southampton   yes   True
# 888   Third       False  NaN  Southampton    no  False
# 889   First        True    C    Cherbourg   yes   True
# 890   Third        True  NaN   Queenstown    no   True

# %% [markdown]
# #### E10: Introduce and handle NaNs to the `titanic` dataset using `random_noise()`:
# 1. Create a new column `LEFT_FROM_noised` by using `random_noise()` on the `LEFT_FROM` column.
# 2. Replace all of the NaNs with "NorthPole" and simultaneously save these outputs to a new column called `LEFT_FROM_denoised`.
# 3. Return the total number of people from each possible location in `LEFT_FROM_denoised`.

# %%
def random_noise(value, threshold=10):
    if random.randint(0,100) < threshold:
        return float('NaN')
    return value

# %%
# SOLUTION
titanic['LEFT_FROM_noised'] = titanic['LEFT_FROM'].map(random_noise)

titanic['LEFT_FROM_denoised'] = titanic['LEFT_FROM_noised'].fillna('NorthPole')

titanic['LEFT_FROM_denoised'].value_counts()

# ONE-LINE RETURN:
# titanic['LEFT_FROM'].map(random_noise).fillna('NorthPole').value_counts()
# Out:
# LEFT_FROM_denoised
# Southampton    575
# Cherbourg      155
# NorthPole       91
# Queenstown      70
# Name: count, dtype: int64

# %%
### YOUR CODE HERE

# Create `LEFT_FROM_noised` column.


# Replace all NaN values in `LEFT_FROM_noised` with "NorthPole"


# Return the total number of people from each possible location in `left_from_denoised`

# %% [markdown]
# #### E11: Return the DataFrame that keeps only the `ALIVE` and `ALONE` columns from the `titanic` dataset.

# %%
# SOLUTION
titanic[['ALIVE', 'ALONE']]
# Out:
#     ALIVE  ALONE
# 0      no  False
# 1     yes  False
# 2     yes   True
# 3     yes  False
# 4      no   True
# ..    ...    ...
# 886    no   True
# 887   yes   True
# 888    no  False
# 889   yes   True
# 890    no   True
#
# [891 rows x 2 columns]

# %%
### YOUR CODE HERE

# %% [markdown]
# ## Extracting quantitative information

# %% [markdown]
# #### E12: Return a summary of of all numeric columns in the `titanic` dataset.
# - This summary should include `count`, `mean`, `std`, `minimum/maxmimum` values, and the `25%/50%/75%` splits.

# %%
# SOLUTION
titanic.describe()
# Out:
#          SURVIVED      PCLASS         AGE  NUM_DEPENDENTS       PARCH  \
# count  891.000000  891.000000  714.000000      891.000000  891.000000
# mean     0.383838    2.308642   29.699118        0.523008    0.381594
# std      0.486592    0.836071   14.526497        1.102743    0.806057
# min      0.000000    1.000000    0.420000        0.000000    0.000000
# 25%      0.000000    2.000000   20.125000        0.000000    0.000000
# 50%      0.000000    3.000000   28.000000        0.000000    0.000000
# 75%      1.000000    3.000000   38.000000        1.000000    0.000000
# max      1.000000    3.000000   80.000000        8.000000    6.000000
#
#              FARE
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
### YOUR CODE HERE

# %% [markdown]
# #### E13: Find the total amount of money that the `titanic` made.

# %%
# SOLUTION
titanic['FARE'].sum()
# Out:
# 28693.9493

# %%
### YOUR CODE HERE

# %% [markdown]
# #### E14: Find the six most expensive tickets.

# %%
# SOLUTION
titanic['FARE'].nlargest(6)
# Out:
# 258    512.3292
# 679    512.3292
# 737    512.3292
# 27     263.0000
# 88     263.0000
# 341    263.0000
# Name: FARE, dtype: float64

# %%
### YOUR CODE HERE

# %% [markdown]
# #### E15: Return the DataFrame that only contains survivors.

# %%
# SOLUTION
titanic[titanic['SURVIVED'] == 1]
# Out:
#      SURVIVED  PCLASS     SEX   AGE  NUM_DEPENDENTS  PARCH     FARE EMBARKED  \
# 1           1       1  female  38.0               1      0  71.2833        C
# 2           1       3  female  26.0               0      0   7.9250        S
# 3           1       1  female  35.0               1      0  53.1000        S
# 8           1       3  female  27.0               0      2  11.1333        S
# 9           1       2  female  14.0               1      0  30.0708        C
# ..        ...     ...     ...   ...             ...    ...      ...      ...
# 875         1       3  female  15.0               0      0   7.2250        C
# 879         1       1  female  56.0               0      1  83.1583        C
# 880         1       2  female  25.0               0      1  26.0000        S
# 887         1       1  female  19.0               0      0  30.0000        S
# 889         1       1    male  26.0               0      0  30.0000        C
#
#       CLASS  ADULT_MALE DECK    LEFT_FROM ALIVE  ALONE LEFT_FROM_noised  \
# 1     First       False    C    Cherbourg   yes  False        Cherbourg
# 2     Third       False  NaN  Southampton   yes   True              NaN
# 3     First       False    C  Southampton   yes  False      Southampton
# 8     Third       False  NaN  Southampton   yes  False      Southampton
# 9    Second       False  NaN    Cherbourg   yes  False        Cherbourg
# ..      ...         ...  ...          ...   ...    ...              ...
# 875   Third       False  NaN    Cherbourg   yes   True        Cherbourg
# 879   First       False    C    Cherbourg   yes  False        Cherbourg
# 880  Second       False  NaN  Southampton   yes  False      Southampton
# 887   First       False    B  Southampton   yes   True      Southampton
# 889   First        True    C    Cherbourg   yes   True        Cherbourg
#
#     LEFT_FROM_denoised
# 1            Cherbourg
# 2            NorthPole
# 3          Southampton
# 8          Southampton
# 9            Cherbourg
# ..                 ...
# 875          Cherbourg
# 879          Cherbourg
# 880        Southampton
# 887        Southampton
# 889          Cherbourg
#
# [342 rows x 16 columns]

# %% [markdown]
# #### E16: Return the DataFrame that only contains first-class females.

# %%
titanic[(titanic['SEX'] == 'female') & (titanic['CLASS'] == 'First')]
# Out:
#      SURVIVED  PCLASS     SEX   AGE  NUM_DEPENDENTS  PARCH      FARE EMBARKED  \
# 1           1       1  female  38.0               1      0   71.2833        C
# 3           1       1  female  35.0               1      0   53.1000        S
# 11          1       1  female  58.0               0      0   26.5500        S
# 31          1       1  female   NaN               1      0  146.5208        C
# 52          1       1  female  49.0               1      0   76.7292        C
# ..        ...     ...     ...   ...             ...    ...       ...      ...
# 856         1       1  female  45.0               1      1  164.8667        S
# 862         1       1  female  48.0               0      0   25.9292        S
# 871         1       1  female  47.0               1      1   52.5542        S
# 879         1       1  female  56.0               0      1   83.1583        C
# 887         1       1  female  19.0               0      0   30.0000        S
#
#      CLASS  ADULT_MALE DECK    LEFT_FROM ALIVE  ALONE LEFT_FROM_noised  \
# 1    First       False    C    Cherbourg   yes  False        Cherbourg
# 3    First       False    C  Southampton   yes  False      Southampton
# 11   First       False    C  Southampton   yes   True              NaN
# 31   First       False    B    Cherbourg   yes  False        Cherbourg
# 52   First       False    D    Cherbourg   yes  False        Cherbourg
# ..     ...         ...  ...          ...   ...    ...              ...
# 856  First       False  NaN  Southampton   yes  False      Southampton
# 862  First       False    D  Southampton   yes   True      Southampton
# 871  First       False    D  Southampton   yes  False      Southampton
# 879  First       False    C    Cherbourg   yes  False        Cherbourg
# 887  First       False    B  Southampton   yes   True      Southampton
#
#     LEFT_FROM_denoised
# 1            Cherbourg
# 3          Southampton
# 11           NorthPole
# 31           Cherbourg
# 52           Cherbourg
# ..                 ...
# 856        Southampton
# 862        Southampton
# 871        Southampton
# 879          Cherbourg
# 887        Southampton
#
# [94 rows x 16 columns]

# %%
### YOUR CODE HERE

# %% [markdown]
# #### E17 People from Cherbourg or Southampton.
# 1. Create a new DataFrame `titanic_ch_so` that only contains the people who originally left from Cherbourg or Southampton; use the original `LEFT_FROM` column.
# 2. Demonstrate that people who originally left from Queenstown are not included in `titanic_ch_so`.

# %%
# SOLUTION
titanic_ch_so = titanic[titanic['LEFT_FROM'].isin(['Cherbourgh', 'Southampton'])]
'Queenstown' in titanic_ch_so['LEFT_FROM']
# Out:
# False

# %%
### YOUR CODE HERE

# Making new DataFrame of only people from Cherbourg or Southampton


# Demonstrating that people from Queenstown are not in new DataFrame

# %% [markdown]
# #### E18: Return the DataFrame of the average numeric value for every numeric column, by `CLASS`.

# %%
# SOLUTION
titanic.groupby(['CLASS'], observed='False').mean(numeric_only=True)
# Out:
#         SURVIVED  PCLASS        AGE  NUM_DEPENDENTS     PARCH       FARE  \
# CLASS
# First   0.629630     1.0  38.233441        0.416667  0.356481  84.154687
# Second  0.472826     2.0  29.877630        0.402174  0.380435  20.662183
# Third   0.242363     3.0  25.140620        0.615071  0.393075  13.675550
#
#         ADULT_MALE     ALONE
# CLASS
# First     0.550926  0.504630
# Second    0.538043  0.565217
# Third     0.649695  0.659878

# %%
### YOUR CODE HERE

# %% [markdown]
# #### E19: Finding the range of values for all numeric columns
# 1. Save a copy of the titanic dataset `titanic_numerics` where only numeric columns are saved
#     - Hint: dtypes are your friend!
# 2. Return the numeric range for each column using `get_range`.

# %%
def get_range(values):
    return values.max() - values.min()

# %%
# SOLUTION
titanic_numerics = titanic.select_dtypes(include='number')
titanic_numerics.apply(get_range)
# Out:
# SURVIVED            1.0000
# PCLASS              2.0000
# AGE                79.5800
# NUM_DEPENDENTS      8.0000
# PARCH               6.0000
# FARE              512.3292
# dtype: float64

# %%
### YOUR CODE HERE

# Save a copy where only numeric columns are saved.


# Return the numeric range for each column using get_range

# %% [markdown]
# #### E20: Return a version of `titanic_numerics` where every value is divided by 2.

# %%
# SOLUTION
titanic_numerics.div(2)
# Out:
#      SURVIVED  PCLASS   AGE  NUM_DEPENDENTS  PARCH      FARE
# 0         0.0     1.5  11.0             0.5    0.0   3.62500
# 1         0.5     0.5  19.0             0.5    0.0  35.64165
# 2         0.5     1.5  13.0             0.0    0.0   3.96250
# 3         0.5     0.5  17.5             0.5    0.0  26.55000
# 4         0.0     1.5  17.5             0.0    0.0   4.02500
# ..        ...     ...   ...             ...    ...       ...
# 886       0.0     1.0  13.5             0.0    0.0   6.50000
# 887       0.5     0.5   9.5             0.0    0.0  15.00000
# 888       0.0     1.5   NaN             0.5    1.0  11.72500
# 889       0.5     0.5  13.0             0.0    0.0  15.00000
# 890       0.0     1.5  16.0             0.0    0.0   3.87500
#
# [891 rows x 6 columns]

# %%
### YOUR CODE HERE

# %% [markdown]
# #### E21: Different kinds of aggregation on `titanic_numerics`
# - Find the median for the ticket price, and find the minimum and maximum ages, in only one DataFrame.

# %%
# SOLUTION
titanic_numerics.agg({'FARE':['median'], 'AGE':['min', 'max']})
# Out:
#            FARE    AGE
# median  14.4542    NaN
# min         NaN   0.42
# max         NaN  80.00

# %% [markdown]
# #### E22: Calculate the Spearman rank correlation between age and ticket price.

# %%
# SOLUTION
titanic[['FARE', 'AGE']].corr(method='spearman')
# Out:
#           FARE       AGE
# FARE  1.000000  0.135051
# AGE   0.135051  1.000000

# %%
# YOUR CODE HERE

# %% [markdown]
# # END
# Thanks for solving!
